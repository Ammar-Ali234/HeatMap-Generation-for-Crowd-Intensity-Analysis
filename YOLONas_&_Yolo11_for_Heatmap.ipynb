# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.98-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.98-py3-none-any.whl (949 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.0/950.0 kB 39.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 58.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 60.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 32.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.8 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.98 ultralytics-thop-2.0.14

# %%
import cv2
from ultralytics import YOLO
from google.colab.patches import cv2_imshow
from super_gradients.training import models

# %%
import cv2
from ultralytics import solutions

# Open video file
cap = cv2.VideoCapture("test.mp4")
assert cap.isOpened(), "Error reading video file"

# Get video properties
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Define video writer (MP4 format)
video_writer = cv2.VideoWriter("heatmap_output.mp4", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# Initialize heatmap generator
heatmap = solutions.Heatmap(
    show=True,  # Show live visualization
    model="yolo_nas_s.pt",  # Ensure correct YOLO-NAS model file
    colormap=cv2.COLORMAP_JET,  # Heatmap color style
    classes=[2, 3, 5, 7],  # Vehicle classes (Car, Motorcycle, Bus, Truck)
)

# Process video
while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video processing complete.")
        break

    # Apply heatmap processing
    results = heatmap(im0)

    # Display results live
    cv2.imshow("Heatmap", results.plot_im)

    # Save processed frame
    video_writer.write(results.plot_im)

    # Exit with 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Cleanup
cap.release()
video_writer.release()
cv2.destroyAllWindows()

# %%
import cv2

from ultralytics import solutions

cap = cv2.VideoCapture("/content/test2.mp4")
assert cap.isOpened(), "Error reading video file"

# Video writer
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
video_writer = cv2.VideoWriter("heatmap_output2_r1.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# For object counting with heatmap, you can pass region points.
#region_points = [(20, 400), (1080, 400)]                                      # line points
# region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360)]              # rectangle region
# region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360), (20, 400)]   # polygon points

# Initialize heatmap object
heatmap = solutions.Heatmap(
    show=True,  # display the output
    model="yolo11n.pt",  # path to the YOLO11 model file
    colormap=cv2.COLORMAP_PARULA,  # colormap of heatmap
    #region=region_points,  # object counting with heatmaps, you can pass region_points
    classes=[2,3,5,7],  # generate heatmap for specific classes i.e person and car.
)

# Process video
while cap.isOpened():
    success, im0 = cap.read()

    if not success:
        print("Video frame is empty or processing is complete.")
        break

    results = heatmap(im0)

    # print(results)  # access the output

    video_writer.write(results.plot_im)  # write the processed frame.

cap.release()
video_writer.release()
cv2.destroyAllWindows()  # destroy all opened windows
# Out:
# Ultralytics Solutions: ✅ {'region': [(20, 400), (1080, 400)], 'show_in': True, 'show_out': True, 'colormap': 12, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'json_file': None, 'records': 5, 'show': True, 'model': 'yolo11n.pt', 'classes': [2, 3, 5, 7]}
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# 0: 640x384 16 cars, 1 motorcycle, 2 trucks, 51.3ms
# Speed: 2.6ms preprocess, 51.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 16 cars, 2 trucks, 10.4ms
# Speed: 3.5ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 16 cars, 1 truck, 13.8ms
# Speed: 3.5ms preprocess, 13.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 17 cars, 1 truck, 13.1ms
# Speed: 3.7ms preprocess, 13.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 17 cars, 1 truck, 11.1ms
# Speed: 3.6ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 18 cars, 1 truck, 10.7ms
# Speed: 4.2ms preprocess, 10.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 18 cars, 1 truck, 13.0ms
# Speed: 3.7ms preprocess, 13.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 18 cars, 2 trucks, 14.8ms
# Speed: 3.7ms preprocess, 14.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}}, total_tracks=20)
#
# 0: 640x384 18 cars, 2 buss, 12.3ms
# Speed: 3.5ms preprocess, 12.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=20)
#
# 0: 640x384 19 cars, 1 bus, 10.9ms
# Speed: 3.7ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=20)
#
# 0: 640x384 17 cars, 2 buss, 2 trucks, 13.5ms
# Speed: 4.4ms preprocess, 13.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=21)
#
# 0: 640x384 18 cars, 1 motorcycle, 2 trucks, 15.5ms
# Speed: 3.6ms preprocess, 15.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=21)
#
# 0: 640x384 17 cars, 2 trucks, 10.8ms
# Speed: 3.8ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 16 cars, 1 bus, 2 trucks, 10.6ms
# Speed: 3.6ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 18 cars, 1 bus, 1 truck, 13.8ms
# Speed: 3.6ms preprocess, 13.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=20)
#
# 0: 640x384 17 cars, 1 bus, 2 trucks, 11.9ms
# Speed: 3.7ms preprocess, 11.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=20)
#
# 0: 640x384 18 cars, 1 bus, 1 truck, 10.2ms
# Speed: 3.6ms preprocess, 10.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=20)
#
# 0: 640x384 17 cars, 1 bus, 1 truck, 10.8ms
# Speed: 4.3ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 17 cars, 1 bus, 1 truck, 12.9ms
# Speed: 4.3ms preprocess, 12.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 16 cars, 1 bus, 13.7ms
# Speed: 3.5ms preprocess, 13.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 17 cars, 1 truck, 10.3ms
# Speed: 3.6ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 17 cars, 1 truck, 10.1ms
# Speed: 3.9ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 16 cars, 2 trucks, 13.4ms
# Speed: 3.7ms preprocess, 13.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 16 cars, 1 bus, 1 truck, 11.0ms
# Speed: 3.5ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 16 cars, 2 trucks, 10.9ms
# Speed: 3.7ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 16 cars, 1 bus, 1 truck, 9.4ms
# Speed: 3.7ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 16 cars, 2 trucks, 13.5ms
# Speed: 4.3ms preprocess, 13.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 16 cars, 2 trucks, 10.9ms
# Speed: 3.8ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 18 cars, 1 bus, 1 truck, 12.9ms
# Speed: 3.6ms preprocess, 12.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=20)
#
# 0: 640x384 17 cars, 2 buss, 1 truck, 9.3ms
# Speed: 3.6ms preprocess, 9.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=20)
#
# 0: 640x384 16 cars, 2 buss, 2 trucks, 11.2ms
# Speed: 3.6ms preprocess, 11.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=20)
#
# 0: 640x384 17 cars, 2 buss, 1 truck, 12.6ms
# Speed: 3.6ms preprocess, 12.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=20)
#
# 0: 640x384 14 cars, 2 buss, 3 trucks, 9.8ms
# Speed: 3.7ms preprocess, 9.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 13 cars, 1 bus, 3 trucks, 13.5ms
# Speed: 3.5ms preprocess, 13.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 15 cars, 1 truck, 10.7ms
# Speed: 3.7ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 15 cars, 2 trucks, 10.4ms
# Speed: 4.7ms preprocess, 10.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 14 cars, 1 bus, 1 truck, 10.0ms
# Speed: 3.5ms preprocess, 10.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 15 cars, 2 trucks, 11.1ms
# Speed: 3.7ms preprocess, 11.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 14 cars, 3 trucks, 14.1ms
# Speed: 3.8ms preprocess, 14.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 16 cars, 1 bus, 10.1ms
# Speed: 3.7ms preprocess, 10.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 16 cars, 1 truck, 10.5ms
# Speed: 5.0ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 16 cars, 1 truck, 13.8ms
# Speed: 4.4ms preprocess, 13.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 16 cars, 1 truck, 11.0ms
# Speed: 3.9ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 17 cars, 11.5ms
# Speed: 3.4ms preprocess, 11.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 16 cars, 1 truck, 10.5ms
# Speed: 3.7ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 15 cars, 1 truck, 10.1ms
# Speed: 3.9ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 16 cars, 11.0ms
# Speed: 3.7ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 16 cars, 18.8ms
# Speed: 3.5ms preprocess, 18.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 14 cars, 1 truck, 10.2ms
# Speed: 3.5ms preprocess, 10.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 14 cars, 12.8ms
# Speed: 3.8ms preprocess, 12.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 640x384 14 cars, 9.7ms
# Speed: 3.6ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 640x384 16 cars, 12.0ms
# Speed: 3.5ms preprocess, 12.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 15 cars, 18.6ms
# Speed: 3.7ms preprocess, 18.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 14 cars, 14.0ms
# Speed: 3.6ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 640x384 13 cars, 1 truck, 13.7ms
# Speed: 3.9ms preprocess, 13.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 640x384 14 cars, 1 truck, 9.8ms
# Speed: 3.6ms preprocess, 9.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 14 cars, 1 bus, 10.0ms
# Speed: 3.7ms preprocess, 10.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 13 cars, 1 bus, 1 truck, 15.8ms
# Speed: 3.4ms preprocess, 15.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 13 cars, 2 trucks, 11.0ms
# Speed: 4.6ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 14 cars, 1 bus, 1 truck, 10.6ms
# Speed: 3.6ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 13 cars, 1 bus, 1 truck, 11.2ms
# Speed: 3.5ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 14 cars, 1 bus, 1 truck, 12.5ms
# Speed: 3.6ms preprocess, 12.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 14 cars, 1 bus, 1 truck, 16.4ms
# Speed: 3.7ms preprocess, 16.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 15 cars, 2 trucks, 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 15 cars, 2 trucks, 10.5ms
# Speed: 3.7ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 15 cars, 2 trucks, 12.5ms
# Speed: 3.6ms preprocess, 12.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 16 cars, 14.1ms
# Speed: 5.9ms preprocess, 14.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 15 cars, 9.7ms
# Speed: 3.7ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 15 cars, 10.2ms
# Speed: 5.0ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 15 cars, 13.2ms
# Speed: 3.7ms preprocess, 13.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 14 cars, 1 truck, 12.1ms
# Speed: 3.4ms preprocess, 12.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 14 cars, 2 trucks, 11.5ms
# Speed: 3.2ms preprocess, 11.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 15 cars, 1 truck, 16.2ms
# Speed: 3.3ms preprocess, 16.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 14 cars, 2 trucks, 13.4ms
# Speed: 4.8ms preprocess, 13.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 15 cars, 2 trucks, 11.9ms
# Speed: 3.6ms preprocess, 11.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 15 cars, 1 bus, 2 trucks, 10.1ms
# Speed: 3.7ms preprocess, 10.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 14 cars, 1 bus, 13.1ms
# Speed: 4.6ms preprocess, 13.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 14 cars, 1 bus, 1 truck, 12.5ms
# Speed: 3.7ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 15 cars, 1 bus, 1 truck, 12.5ms
# Speed: 4.3ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 16 cars, 1 truck, 10.2ms
# Speed: 3.7ms preprocess, 10.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 16 cars, 13.7ms
# Speed: 3.7ms preprocess, 13.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 15 cars, 2 trucks, 11.8ms
# Speed: 3.6ms preprocess, 11.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 15 cars, 2 trucks, 10.8ms
# Speed: 3.6ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 16 cars, 2 trucks, 11.9ms
# Speed: 3.3ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 15 cars, 2 trucks, 12.3ms
# Speed: 3.7ms preprocess, 12.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 16 cars, 2 trucks, 14.3ms
# Speed: 5.1ms preprocess, 14.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 15 cars, 3 trucks, 10.6ms
# Speed: 3.7ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 15 cars, 3 trucks, 12.9ms
# Speed: 3.7ms preprocess, 12.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 15 cars, 1 bus, 3 trucks, 13.0ms
# Speed: 3.7ms preprocess, 13.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 16 cars, 3 trucks, 11.2ms
# Speed: 3.9ms preprocess, 11.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 17 cars, 2 trucks, 13.4ms
# Speed: 3.6ms preprocess, 13.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 17 cars, 2 trucks, 11.1ms
# Speed: 3.7ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 14 cars, 25.4ms
# Speed: 3.5ms preprocess, 25.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 640x384 16 cars, 19.5ms
# Speed: 12.4ms preprocess, 19.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 17 cars, 14.5ms
# Speed: 3.7ms preprocess, 14.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 16 cars, 1 truck, 15.3ms
# Speed: 3.5ms preprocess, 15.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 16 cars, 1 bus, 2 trucks, 21.4ms
# Speed: 3.6ms preprocess, 21.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 18 cars, 1 truck, 17.4ms
# Speed: 5.6ms preprocess, 17.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 17 cars, 1 bus, 1 truck, 12.7ms
# Speed: 3.8ms preprocess, 12.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 16 cars, 2 buss, 1 truck, 12.1ms
# Speed: 6.8ms preprocess, 12.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 18 cars, 1 truck, 15.9ms
# Speed: 8.0ms preprocess, 15.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 15 cars, 3 trucks, 22.2ms
# Speed: 3.7ms preprocess, 22.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 15 cars, 3 trucks, 17.2ms
# Speed: 3.8ms preprocess, 17.2ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 15 cars, 1 bus, 2 trucks, 16.7ms
# Speed: 5.9ms preprocess, 16.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 16 cars, 2 trucks, 15.8ms
# Speed: 3.5ms preprocess, 15.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 14 cars, 3 trucks, 16.5ms
# Speed: 3.5ms preprocess, 16.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 17 cars, 10.3ms
# Speed: 3.9ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 17 cars, 1 truck, 12.1ms
# Speed: 4.1ms preprocess, 12.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 16 cars, 2 trucks, 12.1ms
# Speed: 3.7ms preprocess, 12.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 15 cars, 2 trucks, 11.3ms
# Speed: 3.7ms preprocess, 11.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 17 cars, 1 truck, 11.0ms
# Speed: 6.7ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 17 cars, 2 trucks, 19.6ms
# Speed: 3.6ms preprocess, 19.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 16 cars, 4 trucks, 13.0ms
# Speed: 3.7ms preprocess, 13.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=20)
#
# 0: 640x384 17 cars, 2 trucks, 11.2ms
# Speed: 3.8ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 16 cars, 1 truck, 12.2ms
# Speed: 3.8ms preprocess, 12.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 16 cars, 2 trucks, 12.6ms
# Speed: 4.2ms preprocess, 12.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 18 cars, 1 truck, 13.5ms
# Speed: 4.2ms preprocess, 13.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 17 cars, 12.9ms
# Speed: 4.0ms preprocess, 12.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 17 cars, 1 truck, 10.7ms
# Speed: 3.6ms preprocess, 10.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 17 cars, 10.6ms
# Speed: 3.8ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 19 cars, 12.8ms
# Speed: 3.7ms preprocess, 12.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 18 cars, 1 truck, 15.2ms
# Speed: 5.6ms preprocess, 15.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 18 cars, 1 truck, 10.7ms
# Speed: 3.7ms preprocess, 10.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 18 cars, 1 truck, 11.9ms
# Speed: 3.7ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 18 cars, 1 truck, 18.1ms
# Speed: 3.9ms preprocess, 18.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 18 cars, 1 truck, 12.9ms
# Speed: 3.8ms preprocess, 12.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 18 cars, 1 truck, 10.9ms
# Speed: 3.6ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 18 cars, 1 truck, 11.8ms
# Speed: 3.7ms preprocess, 11.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 18 cars, 1 truck, 10.3ms
# Speed: 3.8ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 17 cars, 1 truck, 14.0ms
# Speed: 3.8ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 17 cars, 1 truck, 9.9ms
# Speed: 3.7ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 17 cars, 1 truck, 9.4ms
# Speed: 3.6ms preprocess, 9.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 17 cars, 1 truck, 9.4ms
# Speed: 3.7ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 17 cars, 1 truck, 12.7ms
# Speed: 5.3ms preprocess, 12.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 15 cars, 1 truck, 11.2ms
# Speed: 3.6ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 15 cars, 1 truck, 12.8ms
# Speed: 4.0ms preprocess, 12.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 14 cars, 2 trucks, 11.2ms
# Speed: 3.8ms preprocess, 11.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 16 cars, 1 truck, 13.6ms
# Speed: 3.7ms preprocess, 13.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 13 cars, 3 trucks, 10.5ms
# Speed: 3.5ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 15 cars, 2 trucks, 9.5ms
# Speed: 3.6ms preprocess, 9.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 15 cars, 2 trucks, 9.9ms
# Speed: 3.6ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 15 cars, 2 trucks, 11.7ms
# Speed: 3.7ms preprocess, 11.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 15 cars, 1 bus, 1 truck, 12.5ms
# Speed: 7.3ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 16 cars, 1 bus, 11.2ms
# Speed: 4.4ms preprocess, 11.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 14 cars, 1 truck, 9.3ms
# Speed: 3.5ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 14 cars, 2 trucks, 12.8ms
# Speed: 3.7ms preprocess, 12.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 14 cars, 1 bus, 1 truck, 12.7ms
# Speed: 3.4ms preprocess, 12.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 14 cars, 3 trucks, 10.1ms
# Speed: 3.6ms preprocess, 10.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 14 cars, 1 bus, 1 truck, 11.4ms
# Speed: 4.5ms preprocess, 11.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 15 cars, 2 trucks, 12.9ms
# Speed: 3.8ms preprocess, 12.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 15 cars, 2 trucks, 10.4ms
# Speed: 3.7ms preprocess, 10.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# ...
#
# 0: 640x384 17 cars, 1 bus, 4 trucks, 14.1ms
# Speed: 3.9ms preprocess, 14.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=22)
#
# 0: 640x384 16 cars, 1 bus, 1 truck, 14.7ms
# Speed: 3.6ms preprocess, 14.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 16 cars, 1 bus, 2 trucks, 13.8ms
# Speed: 3.7ms preprocess, 13.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 16 cars, 1 bus, 3 trucks, 12.9ms
# Speed: 3.4ms preprocess, 12.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=20)
#
# 0: 640x384 16 cars, 2 trucks, 23.9ms
# Speed: 3.6ms preprocess, 23.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 17 cars, 2 trucks, 14.3ms
# Speed: 3.6ms preprocess, 14.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 17 cars, 2 trucks, 9.6ms
# Speed: 3.0ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 17 cars, 1 truck, 10.2ms
# Speed: 3.4ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 17 cars, 2 trucks, 13.6ms
# Speed: 3.4ms preprocess, 13.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=19)
#
# 0: 640x384 16 cars, 2 trucks, 13.0ms
# Speed: 4.1ms preprocess, 13.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=18)
#
# 0: 640x384 15 cars, 2 trucks, 9.9ms
# Speed: 3.8ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 16 cars, 1 truck, 14.5ms
# Speed: 3.7ms preprocess, 14.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 16 cars, 1 truck, 13.9ms
# Speed: 3.7ms preprocess, 13.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 15 cars, 1 bus, 1 truck, 13.2ms
# Speed: 3.8ms preprocess, 13.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 15 cars, 1 bus, 1 truck, 9.3ms
# Speed: 3.2ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 15 cars, 1 truck, 12.9ms
# Speed: 4.1ms preprocess, 12.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 15 cars, 1 truck, 9.9ms
# Speed: 3.5ms preprocess, 9.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 15 cars, 1 truck, 9.9ms
# Speed: 3.6ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 14 cars, 2 trucks, 13.0ms
# Speed: 3.4ms preprocess, 13.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 14 cars, 2 trucks, 13.9ms
# Speed: 3.5ms preprocess, 13.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 14 cars, 2 trucks, 14.6ms
# Speed: 12.5ms preprocess, 14.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 15 cars, 1 truck, 9.7ms
# Speed: 3.8ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 15 cars, 1 truck, 12.5ms
# Speed: 3.6ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 14 cars, 2 trucks, 10.3ms
# Speed: 3.6ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 14 cars, 2 trucks, 12.9ms
# Speed: 3.5ms preprocess, 12.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 13 cars, 2 trucks, 10.7ms
# Speed: 3.5ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 14 cars, 1 truck, 11.1ms
# Speed: 3.7ms preprocess, 11.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 13 cars, 2 trucks, 9.9ms
# Speed: 3.6ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 14 cars, 2 trucks, 15.6ms
# Speed: 4.4ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 15 cars, 1 truck, 14.3ms
# Speed: 3.8ms preprocess, 14.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 14 cars, 2 trucks, 12.8ms
# Speed: 3.7ms preprocess, 12.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 14 cars, 2 buss, 9.5ms
# Speed: 3.7ms preprocess, 9.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 14 cars, 1 bus, 1 truck, 14.8ms
# Speed: 3.6ms preprocess, 14.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 15 cars, 1 bus, 1 truck, 10.8ms
# Speed: 3.6ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 15 cars, 1 bus, 1 truck, 10.5ms
# Speed: 3.6ms preprocess, 10.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 14 cars, 2 buss, 1 truck, 10.4ms
# Speed: 3.6ms preprocess, 10.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 14 cars, 2 buss, 1 truck, 16.0ms
# Speed: 4.3ms preprocess, 16.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=17)
#
# 0: 640x384 14 cars, 1 truck, 10.9ms
# Speed: 3.8ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 14 cars, 1 bus, 1 truck, 9.8ms
# Speed: 3.6ms preprocess, 9.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 14 cars, 1 bus, 15.2ms
# Speed: 3.6ms preprocess, 15.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 14 cars, 1 bus, 1 truck, 11.4ms
# Speed: 3.7ms preprocess, 11.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 14 cars, 1 bus, 1 truck, 10.8ms
# Speed: 3.7ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=16)
#
# 0: 640x384 14 cars, 1 bus, 13.3ms
# Speed: 4.7ms preprocess, 13.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 14 cars, 1 bus, 11.2ms
# Speed: 3.7ms preprocess, 11.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 13 cars, 1 bus, 1 truck, 13.5ms
# Speed: 3.6ms preprocess, 13.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 14 cars, 1 bus, 15.3ms
# Speed: 3.7ms preprocess, 15.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 14 cars, 1 bus, 9.9ms
# Speed: 3.7ms preprocess, 9.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 640x384 12 cars, 1 bus, 11.0ms
# Speed: 3.5ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 640x384 13 cars, 1 bus, 10.0ms
# Speed: 3.9ms preprocess, 10.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 640x384 13 cars, 1 bus, 10.2ms
# Speed: 3.8ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# 🚀 Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'motorcycle': {'IN': 0, 'OUT': 0}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
# Video frame is empty or processing is complete.
